# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data/restaurant_wait_1.csv')
df
# Out:
#     Alt  Bar  Fri  Hun   Pat  Price Rain  Res     Type Est Wait
# 0   Yes   No   No  Yes  Some  £ £ £   No  Yes   French   z  Yes
# 1   Yes   No   No  Yes  Full      £   No   No     Thai   t   No
# 2    No  Yes   No   No  Some      £   No   No   Burger   z  Yes
# 3   Yes   No  Yes  Yes  Full      £  Yes   No     Thai   o  Yes
# 4   Yes   No  Yes   No  Full  £ £ £   No  Yes   French   s   No
# 5    No  Yes   No  Yes  Some    £ £  Yes  Yes  Italian   z  Yes
# 6    No  Yes   No   No  None      £  Yes   No   Burger   z   No
# 7    No   No   No  Yes  Some    £ £  Yes  Yes     Thai   z  Yes
# 8    No  Yes  Yes   No  Full      £  Yes   No   Burger   s   No
# 9   Yes  Yes  Yes  Yes  Full  £ £ £   No  Yes  Italian   o   No
# 10   No   No   No   No  None      £   No   No     Thai   z   No
# 11  Yes  Yes  Yes  Yes  Full      £   No   No   Burger   t  Yes

# %%
X = df.iloc[:,0:10]
y = df.Wait

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(criterion = "entropy")
clf = clf.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-8e1c9f05245d> in <module>()
#       2
#       3 clf = tree.DecisionTreeClassifier(criterion = "entropy")
# ----> 4 clf = clf.fit(X, y)
#
# ~/.local/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     797             sample_weight=sample_weight,
#     798             check_input=check_input,
# --> 799             X_idx_sorted=X_idx_sorted)
#     800         return self
#     801
#
# ~/.local/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
# ...
